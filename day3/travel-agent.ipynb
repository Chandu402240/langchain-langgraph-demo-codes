# %%
# %pip install langchain_ollama

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="qwen3:0.6b")

# %%
from langchain_core.prompts import ChatPromptTemplate
system_template = """You are a travel planning assistant. 
Your task is to help users plan their trips by providing recommendations on destinations, 
accommodations, activities, and dining options based on their preferences and budget. Remove any formatting from your response."""

prompt_template = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("user", """I am planning a trip to {destination} for {duration} days.
                My budget is {budget} USD.
                I enjoy {interests}. Can you suggest an itinerary for me?""")
])

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()

# %%
trip_planner_chain = prompt_template | llm | parser

# %%
def plan_trip(destination: str, duration: int, budget: int, interests: str) -> str:

    # You can take input parameters such as destination, duration, budget, and interests from User
    input = {
        "destination": destination,
        "duration": duration,
        "budget": budget,
        "interests": interests
    }
    itinerary = trip_planner_chain.invoke(input)    
    return itinerary

# %%
from IPython.display import display, Markdown
def render_itinerary(itinerary: str):
    display(Markdown(itinerary))

# %%
result = plan_trip(
    destination="Paris",
    duration=7,
    budget=2000,
    interests="culture, food, nature"
) 
render_itinerary(result)
# Out:
# Here’s a 7-day itinerary for Paris within your budget:
#
# **Day 1:**
# - **Morning:** Explore the Eiffel Tower and Louvre Museum.
# - **Afternoon:** Visit the Louvre and the Seine River.
# - **Evening:** Enjoy local markets and dine at a nearby café.
#
# **Day 2:**
# - **Morning:** Explore the Louvre and Montmartre.
# - **Afternoon:** Visit the Musée d’Orsay and the Seine River.
# - **Evening:** Stay at a mid-range hotel or Airbnb.
#
# **Day 3:**
# - **Morning:** Visit the Seine River and nearby parks.
# - **Afternoon:** Explore the Louvre and the Seine again.
# - **Evening:** Dine at a local market or restaurant.
#
# **Day 4:**
# - **Morning:** Go to the Louvre and the Seine.
# - **Afternoon:** Visit Montmartre and enjoy a view.
# - **Evening:** Stay at a budget-friendly accommodation.
#
# **Day 5:**
# - **Morning:** Explore the Seine River and nearby forests.
# - **Afternoon:** Visit the Musée d’Orsay and the Louvre.
# - **Evening:** Dine at a local café or market.
#
# **Day 6:**
# - **Morning:** Go to the Seine River and a nearby beach.
# - **Afternoon:** Visit the Musée d’Orsay and the Louvre.
# - **Evening:** Stay at a budget-friendly hotel.
#
# **Day 7:**
# - **Morning:** Explore the Seine River and nearby parks.
# - **Afternoon:** Dine at a local market or restaurant.
#
# **Budget Notes:**
# - Accommodation: $100–$200 per night.
# - Activities: $150–$300 total.
# - Dining: $50–$150 total.
#
# Let me know if you’d like further adjustments!
